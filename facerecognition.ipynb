# %%
import cv2 as cv2
import os

# %%
video=cv2.VideoCapture(0)
facedetect=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
count=0

# %%
nameID=str(input("Helloo there! Please enter your name"))
path='Images/'+nameID
isExist=os.path.exists(path)

# %%
if(isExist==True):
    print("Sorry, your name is already registered")
    nameID=str(input("Please submit your name with different initials"))
else:
    os.makedirs(path)

# %%
while True:
    ret,frame=video.read()
    faces=facedetect.detectMultiScale(frame,1.3,5)
    for x,y,w,h in faces:
        count=count+1
        name='./Images/'+nameID+'/'+str(count)+ '.jpg'
        print("Gathering Images......"+name)
        cv2.imwrite(name, frame[y:y+h,x:x+w])
        cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),3)  #color is (0,255,0) and stroke is 3
    cv2.imshow("Window Frame", frame)
    cv2.waitKey(1)
    if(count>250):
        break
video.release()
cv2.destroyAllWindows()
# Out:
# Gathering Images......./Images/puneet/1.jpg
# Gathering Images......./Images/puneet/2.jpg
# Gathering Images......./Images/puneet/3.jpg
# Gathering Images......./Images/puneet/4.jpg
# Gathering Images......./Images/puneet/5.jpg
# Gathering Images......./Images/puneet/6.jpg
# Gathering Images......./Images/puneet/7.jpg
# Gathering Images......./Images/puneet/8.jpg
# Gathering Images......./Images/puneet/9.jpg
# Gathering Images......./Images/puneet/10.jpg
# Gathering Images......./Images/puneet/11.jpg
# Gathering Images......./Images/puneet/12.jpg
# Gathering Images......./Images/puneet/13.jpg
# Gathering Images......./Images/puneet/14.jpg
# Gathering Images......./Images/puneet/15.jpg
# Gathering Images......./Images/puneet/16.jpg
# Gathering Images......./Images/puneet/17.jpg
# Gathering Images......./Images/puneet/18.jpg
# Gathering Images......./Images/puneet/19.jpg
# Gathering Images......./Images/puneet/20.jpg
# Gathering Images......./Images/puneet/21.jpg
# ...
